# %%
import pandas as pd
import numpy as np
from math import e
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import tree
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/zoo_data(For Decision Tree Program).csv')

# %%
df1=df.iloc[:,  12:15]
target=df.iloc[:,16]
target
# Out:
# 0     1
# 1     4
# 2     1
# 3     1
# 4     1
#      ..
# 95    1
# 96    6
# 97    1
# 98    7
# 99    2
# Name: 1.7, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(df1,target,test_size=.33)

# %%
from sklearn.tree import DecisionTreeClassifier
c=DecisionTreeClassifier(criterion='entropy')
c.fit(xtrain,ytrain)
ypred=c.predict(xtest)

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.9696969696969697

# %%
fig=plt.figure(figsize=(25,30))
_=tree.plot_tree(c,filled=True)
